# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallika-2005/pandas./blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data=pd.read_csv("/Diabetes Missing Data (1).csv")
data
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(data)
data
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
df.head(30)
# Out:
#     Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0          6    148.0          72.0       35.0            NaN  33.6
# 1          1     85.0          66.0       29.0            NaN  26.6
# 2          8    183.0          64.0        NaN            NaN  23.3
# 3          1     89.0          66.0       23.0           94.0  28.1
# 4          0    137.0          40.0       35.0          168.0  43.1
# 5          5    116.0          74.0        NaN            NaN  25.6
# 6          3     78.0          50.0       32.0           88.0  31.0
# 7         10    115.0           NaN        NaN            NaN  35.3
# 8          2    197.0          70.0       45.0          543.0  30.5
# 9          8    125.0          96.0        NaN            NaN   NaN
# 10         4    110.0          92.0        NaN            NaN  37.6
# 11        10    168.0          74.0        NaN            NaN  38.0
# 12        10    139.0          80.0        NaN            NaN  27.1
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.axes[1]
# Out:
# Index(['Pregnant', 'Glucose', 'Diastolic_BP', 'Skin_Fold', 'Serum_Insulin',
#        'BMI', 'Diabetes_Pedigree', 'Age', 'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pregnant           768 non-null    int64
#  1   Glucose            763 non-null    float64
#  2   Diastolic_BP       733 non-null    float64
#  3   Skin_Fold          541 non-null    float64
#  4   Serum_Insulin      394 non-null    float64
#  5   BMI                757 non-null    float64
#  6   Diabetes_Pedigree  768 non-null    float64
#  7   Age                768 non-null    int64
#  8   Class              768 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %%
count=df.isnull().sum()
print(count)
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %%
df.nunique()
# Out:
# Pregnant              17
# Glucose              135
# Diastolic_BP          46
# Skin_Fold             50
# Serum_Insulin        185
# BMI                  247
# Diabetes_Pedigree    517
# Age                   52
# Class                  2
# dtype: int64

# %%
df1=df.copy()
df1
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
IndicesMissingRows=df1.isnull().any(axis=1)
MissingInRows=df1[IndicesMissingRows]
print(MissingInRows)
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 5           5    116.0          74.0        NaN            NaN  25.6
# 7          10    115.0           NaN        NaN            NaN  35.3
# ..        ...      ...           ...        ...            ...   ...
# 761         9    170.0          74.0       31.0            NaN  44.0
# 762         9     89.0          62.0        NaN            NaN  22.5
# 764         2    122.0          70.0       27.0            NaN  36.8
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
allmedians=df1.median(skipna=True,numeric_only=True)
med1=allmedians[1]
med2=allmedians[2]
med3=allmedians[3]
med4=allmedians[4]
med5=allmedians[5]
# Out:
# <ipython-input-26-7fdc579c8050>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   med1=allmedians[1]
# <ipython-input-26-7fdc579c8050>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   med2=allmedians[2]
# <ipython-input-26-7fdc579c8050>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   med3=allmedians[3]
# ...

# %%
allmedians
# Out:
# Pregnant               3.0000
# Glucose              117.0000
# Diastolic_BP          72.0000
# Skin_Fold             29.0000
# Serum_Insulin        125.0000
# BMI                   32.3000
# Diabetes_Pedigree      0.3725
# Age                   29.0000
# Class                  0.0000
# dtype: float64

# %%
df1=df1.fillna({"Glucose":med1})
df1
df1=df1.fillna({"Skin_Fold":med2})
df1
df1=df1.fillna({"Serum_Insulin":med3})
df1
df1=df1.fillna({"BMI":med4})
df1
df1=df1.fillna({"Diabetes_ Pedigree":med5})
df1
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0           29.0  33.6
# 1           1     85.0          66.0       29.0           29.0  26.6
# 2           8    183.0          64.0       72.0           29.0  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0           29.0  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0       72.0           29.0  30.1
# 767         1     93.0          70.0       31.0           29.0  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
df1=df1.fillna({"Glucose":med1})
df1
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
allmodes=df1.mode(skipna=True,numeric_only=True)
mod1=allmodes[1]
mod2=allmodes[2]
mod3=allmodes[3]
mod4=allmodes[4]
mod5=allmodes[5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-96fbd2ab569b> in <cell line: 1>()
# ----> 1 allmodes=df1.mode(skipna=True,numeric_only=True)
#       2 mod1=allmodes[1]
#       3 mod2=allmodes[2]
#       4 mod3=allmodes[3]
#       5 mod4=allmodes[4]
#
# TypeError: DataFrame.mode() got an unexpected keyword argument 'skipna'
