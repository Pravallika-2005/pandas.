# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallika-2005/pandas./blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/sample1 (1).csv')

# %%
data
# Out:
#         first      last
# 0       Jorge     Frank
# 1      Hunter    Moreno
# 2      Esther    Guzman
# 3      Dennis  Stephens
# 4      Nettie  Franklin
# ..        ...       ...
# 95      Brett    Miller
# 96   Adelaide    Phelps
# 97        Leo   Walters
# 98     Samuel   Schmidt
# 99  Elizabeth    Gordon
#
# [100 rows x 2 columns]

# %%
data.head()
# Out:
#     first      last
# 0   Jorge     Frank
# 1  Hunter    Moreno
# 2  Esther    Guzman
# 3  Dennis  Stephens
# 4  Nettie  Franklin

# %%
data.tail()
# Out:
#         first     last
# 95      Brett   Miller
# 96   Adelaide   Phelps
# 97        Leo  Walters
# 98     Samuel  Schmidt
# 99  Elizabeth   Gordon

# %%
data.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-118f55e0b3d0> in <cell line: 1>()
# ----> 1 data.plot()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1029                     data.columns = label_name
#    1030
# -> 1031         return plot_backend.plot(data, kind=kind, **kwargs)
#    1032
#    1033     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
# ...

# %%
data.describe()
# Out:
#          first      last
# count      100       100
# unique      89        90
# top     Dennis  Matthews
# freq         3         2
